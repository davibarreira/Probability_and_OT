# %%
using Distributions, StatsPlots, Plots
using LaTeXStrings
using ColorSchemes
gr()
# Out:
# Plots.GRBackend()

# %%
theme(:vibrant)

# %%
p = plot(Uniform(0,1),-1,2,label=L"X_1",linewidth = 3)
plot!(Uniform(3,4),2,5,label=L"X_2",linewidth = 3)
plot!(Uniform(6,7),5,8,label=L"X_3",linewidth = 3,framestyle=:box,grid=false,legend=:outertopright,legendfontsize=12)

# %%
savefig(p,"./images/Distributions_Distances.png")

# %%
N = []
μ = []
p = plot()
n = 5
for i = 1:n
    v = 4*randn()
    push!(μ,v)
    push!(N,Normal(v,1))
    plot!(N[i],linewidth = 2,legend = false,framestyle=:box,grid=false)
end
# p2 =  plot(Normal(mean(μ)),linewidth = 2,legend = false,framestyle=:box,grid=false)

p
